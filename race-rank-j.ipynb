# %%
from __future__ import division
import pandas as pd
import numpy as np
import sys
import gc
from enum import Enum

class Algorithm(Enum):
    # LFZB = "LFZB"
    # MFZB = "MFZB"
    RACER = "RACER"
    RACRANK = "RACRANK"
    # Manhattan = "Manhattan"

class Discretization:

    @staticmethod
    def basedOnEntropy(x : np.ndarray):
        labelSet = set(x[:,1]);
        labelMap = {}
        t = 0;
        for element in labelSet:
            labelMap[element] = t;
            t+=1;
        for i in range(0, len(x)):
            x[i, 1] = labelMap[x[i, 1]];

        sortedX = x[x[:, 0].argsort()];

        featureValues = sortedX[:, 0];
        featureValues = np.unique(featureValues);
        if featureValues.shape[0] < 2:
            # print("one feature had unique value -> shape : {0}".format(featureValues.shape[0]));
            return np.zeros(x.shape[0], dtype=int);

        condidateCutPoints = np.zeros(len(featureValues)-1);

        for i in range(0, len(featureValues)-1):
            condidateCutPoints[i] = (featureValues[i] + featureValues[i+1])/2;

        selectedCutPointIndex = -1;
        minEntropy = sys.float_info.max;
        for i in range(0, len(condidateCutPoints)):
            ent = Discretization.__entropy(sortedX, condidateCutPoints[i], len(labelSet));
            if ent < minEntropy :
                minEntropy = ent;
                selectedCutPointIndex = i;
        #print("cutPoint : {0}".format(condidateCutPoints[selectedCutPointIndex]));
        # del sortedX
        # del featureValues
        # gc.collect()

        return Discretization.__generateNewData(x[:,0], condidateCutPoints[selectedCutPointIndex]);

    @staticmethod
    def __generateNewData(data : np.ndarray, cutpoint):
        newData = np.zeros(len(data), dtype=int);
        for i in range(0, len(data)):
            if(data[i] <= cutpoint):
                newData[i] = 0;
            else:
                newData[i] = 1;
        return newData;

    @staticmethod
    def __entropy(data : np.ndarray, cutpoint, numOfClasses):
        entropy = 0;
        leftBucketInstanceNumber = 0;
        rightBucketInstanceNumber = 0;
        allInstanceNumber = len(data);
        leftBucket = np.zeros(numOfClasses);
        rightBucket = np.zeros(numOfClasses);
        for i in range(0, len(data)):
            if data[i, 0] <= cutpoint :
                leftBucket[int(data[i, 1])] += 1;
                leftBucketInstanceNumber += 1;
            else:
                rightBucket[int(data[i, 1])] += 1;
                rightBucketInstanceNumber += 1;


        leftBucketClassProbability = leftBucket / leftBucketInstanceNumber;
        rightBucketClassProbability = rightBucket / rightBucketInstanceNumber;
        leftBucketEntropy = np.sum(leftBucketClassProbability * np.log2(leftBucketClassProbability, out=np.zeros_like(leftBucketClassProbability), where=(leftBucketClassProbability!=0)));
        rightBucketEntropy = np.sum(rightBucketClassProbability * np.log2(rightBucketClassProbability, out=np.zeros_like(rightBucketClassProbability), where=(rightBucketClassProbability!=0)));

        entropy = (leftBucketInstanceNumber / allInstanceNumber) * leftBucketEntropy + (rightBucketInstanceNumber / allInstanceNumber) * rightBucketEntropy;
        entropy = -1 * entropy;
        return entropy;

# %%
from typing import Tuple, Union
import pandas as pd
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import accuracy_score
from typing import Union
import numpy as np
import networkx as nx
import gc

np.bool = np.bool_

class ROPACPreprocesser:
    def __init__(self, framework="numpy"):
        assert framework in [
            "numpy",
            "torch",
        ], "framework must be either 'numpy' or 'torch'"
        self.framework = framework

    def fit_transform(
        self, data: Union[pd.DataFrame, np.ndarray], dataTypes
    ):
        """Preprocesses the dataset by replacing nominal values with dummy variables.
        Converts to torch bool tensors and returns the dataset. All numerical values are discretized
        into equal-sized bins using a quantile-based method (pd.qcut).
        Args:
            X (pandas.DataFrame or np.ndarray): features vector
            y (pandas.DataFrame or np.ndarray): targets vector
        Returns:
            X (torch.Tensor or np.ndarray): features vector
            y (torch.Tensor or np.ndarray): targets vector
        """

        classIndex = data.shape[1]-1;

        X = data[:, 0:data.shape[1]-1];
        y = data[:, data.shape[1]-1];
        


        numAttrIndex = [i for i, t in enumerate(dataTypes) if t == 'numeric' or t == 'integer' or t == 'real'];

        if numAttrIndex:
            for num in numAttrIndex:
                newData = Discretization.basedOnEntropy(data[:,[num,classIndex]]);
                X[:, num] = newData;
       
        X = pd.get_dummies(pd.DataFrame(X)).to_numpy()
       
        y = pd.get_dummies(y).to_numpy()
        if self.framework == "torch":
            import torch

            X, y = torch.tensor(X, dtype=torch.bool), torch.tensor(y, dtype=torch.bool)
        return X, y


    def matrix_to_list(adj_matrix):
        edges = []
        rows, cols = np.where(adj_matrix > 0)

        for i in range(len(rows)):
            weight = adj_matrix[rows[i]][cols[i]]
            edges.append((rows[i], cols[i], {'weight': weight} ))
        gc.collect()
        return edges


from numpy import (
    logical_and as AND,
    logical_not as NOT,
    logical_or as OR,
    logical_xor as XOR,
)


def XNOR(input: np.ndarray, other: np.ndarray) -> np.ndarray:
    """Computes the XNOR gate. (semantically the same as `input == other`)
    Args:
        input (np.ndarray): Input tensor
        other (np.ndarray): Other input tensor
    Returns:
        np.ndarray: Output tensor
    """
    return NOT(XOR(input, other)).astype(bool)


class ROPAC:
    def __init__(
        self,
        alpha=0.9,
        fitness_fn="weighted_average",
        gamma=0.6,
        suppress_warnings=False,
        benchmark=False,
    ):
        """Initialize the ROPAC class.
        Args:
            alpha (float, optional): Value of alpha according to the ROPAC paper. Defaults to 0.9.
            fitness_function (str in ["weighted_average", "f-beta"], optional): Choice of fitness function to use. Defaults to "weighted_average".
            gamma (float, optional): Weight given to coverage score during closest_matching if rules cannot perfectly describe a given input.
                                      values > 0.5 recommended. Defaults to 0.6.
            suppress_warnings (bool, optional): Whether to suppress any warnings raised during prediction. Defaults to False.
            benchmark (bool, optional): Whether to time the `fit` method for benchmark purposes. Defaults to False.
        """
        self._alpha, self._beta = alpha, 1 - alpha
        self._gamma = gamma

        assert fitness_fn in [
            "weighted_average",
            "f-beta",
        ], "fitness_function must be either 'weighted_average' or 'f-beta'"
        self._fitness_fn = (
            self._fitness_weighted_avg
            if fitness_fn == "weighted_average"
            else self._fitness_f_beta
        )
        self._fitness_fn_name = (
            "Weighted Average" if fitness_fn == "weighted_average" else "F-Beta"
        )

        self._suppress_warnings = suppress_warnings

        self._benchmark = benchmark

        self._has_fit = False

        self.cardinality =[]


    def fit(self, X: np.ndarray, y: np.ndarray, stop_merging = False, algorithm="RACRANK", sorting=False, reverse = False) -> None:
        """Fits the ROPAC algorithm on top of input data X and targets y.
        The code is written in a way that it is similar to the pseudo-code provided in the ROPAC paper.
        Args:
            X (np.ndarray): features vector
            y (np.ndarray): targets vector
            stop_merging (Boolean): If it's true, it means after merging two rules, the algorithm stops current iteration
            algorithm (String): Type of algorithm (LFZB or MFZB)
        """
        # print(f"Fit function descreption:\n  algorithm={algorithm}, stop_merging={stop_merging} ,  sorting={sorting}, reverse={reverse}")

        if self._benchmark:
            from time import perf_counter

            tic = perf_counter()

        self._X, self._y = X, y
        self._cardinality, self._rule_len = self._X.shape
        self._classes = np.unique(self._y, axis=0)
        self._class_indices = {
            self._label_to_int(cls): np.where(np.min(XNOR(self._y, cls), axis=-1))[0]
            for cls in self._classes
        }
        


        self._create_init_rules()
        # print('**** created init rules')
        # self.display_init_rules()

        #To use ROPAC-M, uncomment the next line. You can only use one of the following lines at a time.
        #self.MFZB(self._extants_if, self._extants_then)
        # self.LFZB(self._extants_if, self._extants_then)

        if algorithm.value == 'MFZB' or algorithm.value == 'LFZB':
            self.space_search(self._extants_if, self._extants_then,algorithm,sorting, reverse )
            self._generalize_extants()


        for cls in self._class_indices.keys():
            indices = self._class_indices[cls]
           
            i, j = np.triu_indices(len(indices), k=1)
            i, j = indices[i], indices[j]
            rule_iterator=[]
            if( algorithm.value =='RACRANK' or algorithm.value == 'Manhattan' ):
                current_list = np.array([self._X[rule_index] for rule_index in indices ])
                # print(f'current_list shape: {current_list.shape}')
                # print(f'current_list: {current_list}')
                num_rules = current_list.shape[0]
                intersection_matrix = np.zeros((num_rules, num_rules))
                manhattan_matrix = np.zeros((num_rules, num_rules))

                for i in range(num_rules):
                    for j in range(i+1, num_rules):
                        intersection_matrix[i, j] = np.sum(current_list[i] & current_list[j])
                        intersection_matrix[j, i] = intersection_matrix[i, j]
                
                if( algorithm.value =='RACRANK' and num_rules > 1):
                    edges = ROPACPreprocesser.matrix_to_list(intersection_matrix)

                    # del intersection_matrix
                    # del current_list
                    # gc.collect()

                    G = nx.DiGraph(edges)
                    G = nx.DiGraph()
                    # G = nx.path_graph(len(edges))
                    G.add_edges_from(edges)

                    network_values = nx.pagerank(G, weight='weight')

                    # network_values = nx.eigenvector_centrality(G)
                    # network_values = nx.betweenness_centrality(G)

                    gc.collect()
                    sorted_nodes = sorted(network_values.items(), key=lambda x: x[1], reverse=reverse)
                    rule_iterator = [indices[node] for node, _ in sorted_nodes]
                elif( algorithm.value == 'Manhattan' ):
                    sorted_nodes = np.argsort(-intersection_matrix)
                    rule_iterator = [indices[node] for node in sorted_nodes]
                    # print(f'sorted_nodes: \n {sorted_nodes}')

                # print(f'rule_iterator: {rule_iterator}')
                # print('**** rule_iterator created ')

                # del sorted_nodes
                # del edges
                # del pagerank_values
                # del G
                # gc.collect()

            elif( algorithm.value == 'RACER' and sorting):
                # Count the number of 1s in each bit position across all rules
                bit_counts = [sum(True for rule_index in indices if self._X[rule_index][r]) for r in range(len(self._X[0]))]
                current_list = np.array([self._X[rule_index] for rule_index in indices ])
                sum_base = np.sum(current_list * bit_counts ,axis=1)
                sort_indices_sum = np.argsort(-sum_base) if reverse else np.argsort(sum_base)
                rule_iterator = sort_indices_sum
            else:
                rule_iterator = indices


            # print('rule_iterator: \n', rule_iterator)
            # del indices
            # gc.collect()

            tmp_number=0
            
            for i in range(len(self._class_indices[cls])):
                for j in range(i + 1, len(self._class_indices[cls])):
                  # composed = self._process_rules(indices[i], indices[j])
                    composed = self._process_rules(rule_iterator[i], rule_iterator[j])
                    if(stop_merging and composed):
                        break
            # if rule_iterator:
            #     del rule_iterator
            #     gc.collect()
        gc.collect()
        independent_indices = ~(self._extants_covered)
        self._extants_if, self._extants_then, self._fitnesses = (
            self._extants_if[independent_indices],
            self._extants_then[independent_indices],
            self._fitnesses[independent_indices] ,
        )
        
        del independent_indices
        gc.collect()
        self._generalize_extants()
        
        args = np.argsort(self._fitnesses)[::-1]
        self._final_rules_if, self._final_rules_then, self._fitnesses = (
            self._extants_if[args],
            self._extants_then[args],
            self._fitnesses[args],
        )

        del args
        gc.collect()

        self._has_fit = True

        if self._benchmark:
            self._bench_time = perf_counter() - tic

    def space_search(self, base_array, base_result, algorithm ,  sorting = False, reverse=False):
        """
        Searching the space to generate new rules according to the algorithm.
        Args:
            base_array ( np.ndarray): Features matrix
            base_result (np.ndarray): Targets vector
            algorithm (String): Type of algorithm (LFZB or MFZB)


        """
        if(algorithm.value == 'LFZB'):
            self.LFZB(base_array, base_result, sorting, reverse)
        else:
            self.MFZB(base_array, base_result, sorting, reverse)


    def MFZB(self, base_array, base_result, sorting = False, reverse=False):
        """
        Most Frequent Zero Bit: This is the implementation of the rule optimization function in ROPAC-M
        """
        # Count the number of 1s in each bit position across all rules
        bit_counts = [sum(1 for rule in base_array if rule[i]) for i in range(len(base_array[0]))]
        # print('bit_counts: \n', bit_counts)
        if(sorting):
            sum_base = np.sum(  base_array * bit_counts ,axis=1)
            # print('sum_base: \n', sum_base)
            sort_indices_sum = np.argsort(-sum_base) if reverse else np.argsort(sum_base)
            # print('sort_indices_sum: \n', sort_indices_sum)
            rule_iterator = sort_indices_sum
            # sorted_sum_base = np.sort(sum_base, axis=0) if reverse else np.sort(sum_base, axis=0)
            # print('sorted_num_array: \n',sorted_sum_base)
        else:
            rule_iterator = range(len(base_array))

        for i in rule_iterator:
            temp_result = base_array[i]
            temp_fitness = self._fitnesses[i]
            false_indices = [idx for idx, value in enumerate(base_array[i]) if not value]

            if not false_indices:
                continue

            # Sort the false indices based on the number of 1s in the corresponding bit position
            sorted_indices = sorted(false_indices, key=lambda idx: bit_counts[idx], reverse=True)

            for index in sorted_indices:
                new_array = base_array[i].copy()
                new_array[index] = True
                fitness = self._fitness_fn(new_array, base_result[i])

                if fitness > temp_fitness:
                    temp_fitness = fitness
                    temp_result = new_array
                    break  # Stop iterating if a better fitness is found

            self._extants_if[i] = temp_result
            self._fitnesses[i] = temp_fitness



    def LFZB(self, base_array, base_result,  sorting = False, reverse=False):
        """
        Least Frequent Zero Bit: This is the implementation of the rule optimization function in ROPAC-L
        """
        # Count the number of 1s in each bit position across all rules
        bit_counts = [sum(1 for rule in base_array if rule[i]) for i in range(len(base_array[0]))]
        
        if(sorting):
            sum_base = np.sum(  base_array * bit_counts ,axis=1)
            sort_indices_sum = np.argsort(-sum_base) if reverse else np.argsort(sum_base)
            rule_iterator = sort_indices_sum
        else:
            rule_iterator = range(len(base_array))



        for i in rule_iterator:
            temp_result = base_array[i]
            temp_fitness = self._fitnesses[i]

            false_indices = [idx for idx, value in enumerate(base_array[i]) if not value]
            
            if not false_indices:
                continue

            # Sort the false indices based on the number of 1s in the corresponding bit position
            sorted_indices = sorted(false_indices, key=lambda idx: bit_counts[idx])

            for index in sorted_indices:
                new_array = base_array[i].copy()
                new_array[index] = True
                fitness = self._fitness_fn(new_array, base_result[i])

                if fitness > temp_fitness:
                    temp_fitness = fitness
                    temp_result = new_array
                    break  # Stop iterating if a better fitness is found

            self._extants_if[i] = temp_result
            self._fitnesses[i] = temp_fitness


    def predict(self, X: np.ndarray, convert_dummies=True) -> np.ndarray:
        """Given input X, predict label using ROPAC
        Args:
            X (np.ndarray): input features vector
            convert_dummies (bool): whether to convert the output to a one-dimensional array
        Returns:
            np.ndarray: label as predicted by ROPAC
        """
        assert self._has_fit, "ROPAC has not been fit yet."
        labels = np.zeros((len(X), self._final_rules_then.shape[1]), dtype=bool)
        found = np.zeros(len(X), dtype=bool)
        for i in range(len(self._final_rules_if)):
            covered = self._covered(X, self._final_rules_if[i])
            labels[AND(covered, NOT(found))] = self._final_rules_then[i]
            found[covered] = True
            if found.sum() == len(X):  # -> every instance was matched to a rule
                break

        all_found = found.sum() == len(X)
        if not all_found:
            # print(
            #     f"Warning: ROPAC was unable to find a perfect match for {len(X) - found.sum()} instances out of {len(X)}."
            # )
            # print(
            #     "Labels for these instances will be determined by a closest match algorithm."
            # )
            leftover_indices = np.where(~found)[0]
            for idx in leftover_indices:
                labels[idx] = self._closest_match(X[idx])

        if convert_dummies:
            labels = np.argmax(labels, axis=-1)

        return labels

    def display_rules(self):
        
        """Print out the final rules"""
        
        assert self._has_fit, "ROPAC has not been fit yet."
        
        print("Algorithm Parameters:")
        print(f"\t- Fitness Function: {self._fitness_fn_name}")
        print(f"\t- Alpha: {self._alpha}")
        print(f"\t- Gamma: {self._gamma}")
        if self._benchmark:
            print(f"\t- Compute Device: CPU")
            print(f"\t- Time to fit: {self._bench_time}s")
        print(
            f"\nFinal Rules ({len(self._final_rules_if)} total): (if --> then (label) | fitness)"
        )
        for i in range(len(self._final_rules_if)):
            print(
                f"\t{np.array2string(self._final_rules_if[i].astype(int), separator='')} -->"
                f" {np.array2string(self._final_rules_then[i].astype(int), separator='')}"
                f" ({np.argmax(self._final_rules_then[i].astype(int))})"
                f" | {self._fitnesses[i]}"
            )

    def _closest_match(self, X: np.ndarray) -> np.ndarray:
        """Find the closest matching rule to `X`
        Args:
            X (np.ndarray): input `X`
        Returns:
            np.ndarray: matched rule
        """
        int_X = X.astype(int)  # <- cast boolean array to integer array
        overlap = OR(NOT(int_X), AND(self._final_rules_if, int_X)).sum(axis=-1)
        overlap = overlap / self._rule_len  # -> normalize by rule length
        scores = np.multiply(self._gamma * overlap, (1 - self._gamma) * self._fitnesses)
        argmax = np.argmax(scores)
        return self._final_rules_then[argmax]

    def score(self, X_test: np.ndarray, y_test: np.ndarray) -> float:
        """Returns accuracy on the provided test data
        Args:
            X_test (np.ndarray): test features vector
            y_test (np.ndarray): test targets vector
        Returns:
            float: accuracy score, F1 score
        """
        assert self._has_fit, "ROPAC has not been fit yet."
        X_test, y_test = X_test.astype(np.float32), y_test.astype(np.float32)
        if y_test.ndim != 1 and y_test.shape[1] != 1:
            y_test = np.argmax(y_test, axis=-1)
        y_pred = self.predict(X_test)

        # return accuracy_score(y_test, y_pred), f1_score(y_test, y_pred, average='weighted')
        return {
                'accuracy': accuracy_score(y_test, y_pred),
                'f1_score': f1_score(y_test, y_pred, average='weighted')
              }

    def _fitness_weighted_avg(
        self, rule_if: np.ndarray, rule_then: np.ndarray
    ) -> float:
        """Returns fitness for a given rule according to the ROPAC paper
        Args:
            rule_if (np.ndarray): if part of a rule (x)
            rule_then (np.ndarray): then part of a rule (y)
        Returns:
            float: fitness score for the rule as defined in the ROPAC paper
        """

        n_covered, n_correct = self._confusion(rule_if, rule_then)
        if n_covered != 0 :
            accuracy = n_correct / n_covered
            coverage = n_covered / self._cardinality
        else :
            accuracy = 0
            coverage = 0

        return self._alpha * accuracy + self._beta * coverage

    def _fitness_f_beta(self, rule_if: np.ndarray, rule_then: np.ndarray) -> np.ndarray:
        """Returns f-beta-score fitness for a given rule
        Args:
            rule_if (np.ndarray): if part of a rule (x)
            rule_then (np.ndarray): then part of a rule (y)
        Returns:
            np.ndarray: f-beta-score fitness for the rule
        """
        # `beta` in f-beta-score is chosen such that recall is considered `beta` times as important as precision
        # https://en.wikipedia.org/wiki/F-score
        beta = self._beta / self._alpha
        n_covered, n_correct = self._confusion(rule_if, rule_then)
        accuracy = n_correct / n_covered
        coverage = n_covered / self._cardinality
        return (
            (1 + beta**2) * (accuracy * coverage) / (beta**2 * accuracy + coverage)
        )

    def _covered(self, X: np.ndarray, rule_if: np.ndarray) -> np.ndarray:
        """Returns indices of instances in `X` that are covered by `rule_if`.
        Note that rule covers instance if EITHER of the following holds in a bitwise manner:
        1. instance[i] == 0
        2. instance[1] == 1 AND rule[i] == 1
        Args:
            X (np.ndarray): instances
            rule_if (np.ndarray): if part of rule (x)
        Returns:
            np.ndarray: An array containing indices of instances in `X_same_class` that are covered by `rule_if`
        """
        covered = OR(NOT(X[:self._cardinality,:]), AND(rule_if, X[:self._cardinality,:])).min(axis=-1)
        return covered

    def _confusion(
        self, rule_if: np.ndarray, rule_then: np.ndarray
    ) -> Tuple[np.ndarray, np.ndarray]:
        """Returns n_correct and n_covered for instances classified by a rule.
        Args:
            rule_if (np.ndarray): if part of rule (x)
            rule_then (np.ndarray): then part of rule (y)
        Returns:
            Tuple[np.ndarray, np.ndarray]: (n_covered, n_correct)
        """
        covered = self._covered(self._X, rule_if)
        covered_mask = np.zeros(self._cardinality, dtype=bool)
        covered_mask[:self._cardinality] = covered
        n_covered = covered.sum()
        y_covered = self._y[covered_mask]
        n_correct = XNOR(y_covered, rule_then).min(axis=-1).sum()
        return n_covered, n_correct

    def display_init_rules(self, num=None):
        """Print out the init rules"""
        print("Print out the init rules")
        for i in range(num if num else  len(self._extants_if)):
            print(
                f"\t{np.array2string(self._extants_if[i].astype(int), separator='')} -->"
                f" {np.array2string(self._extants_then[i].astype(int), separator='')}"
                f" ({np.argmax(self._extants_then[i].astype(int))})"
                f" | {self._fitnesses[i]}"
            )

    def _create_init_rules(self):
        """Creates an initial set of rules from the input feature vectors"""
        self._extants_if = self._X.copy()
        self._extants_then = self._y.copy()
        self._extants_covered = np.zeros(len(self._X), dtype=bool)
        self._fitnesses = np.array(
            [
                self._fitness_fn(rule_if, rule_then)
                for rule_if, rule_then in zip(self._X, self._y)
            ]
        )





    def _composable(self, idx1: int, idx2: int) -> bool:
        """Returns true if two rules indicated by their indices are composable
        Args:
            idx1 (int): index of the first rule
            idx2 (int): index of the second rule
        Returns:
            bool: True if labels match and neither of the rules are covered. False otherwise.
        """
        labels_match = XNOR(self._extants_then[idx1], self._extants_then[idx2]).min() # This line is not nessecary since we already check this
        return (
            labels_match
            and not self._extants_covered[idx1].all()
            and not self._extants_covered[idx2].all()
        )

    def _process_rules(self, idx1: int, idx2: int):
        """Process two rules indicated by their indices
        Args:
            idx1 (int): index of the first rule
            idx2 (int): index of the second rule
        """
        composed = False
        if self._composable(idx1, idx2):
            composition = self._compose(self._extants_if[idx1], self._extants_if[idx2])
            composition_fitness = self._fitness_fn( composition, self._extants_then[idx1])

            if composition_fitness > np.maximum(self._fitnesses[idx1], self._fitnesses[idx2]):
                self._update_extants(idx1, composition, self._extants_then[idx1], composition_fitness)
                composed = True

        return composed

    def _compose(self, rule1: np.ndarray, rule2: np.ndarray) -> np.ndarray:
        """Composes rule1 with rule2
        Args:
            rule1 (np.ndarray): the first rule
            rule2 (np.ndarray): the second rule
        Returns:
            np.ndarray: The composed rule which is simply the bitwise OR of the two rules
        """
        return OR(rule1, rule2)

    def _update_extants(
        self,
        index: int,
        new_rule_if: np.ndarray,
        new_rule_then: np.ndarray,
        new_rule_fitness: np.ndarray,
    ):
        """Remove all rules from current extants that are covered by `new_rule`.
        Then append new rule to extants.
        Args:
            index (int): index of `new_rule`
            new_rule_if (np.ndarray): if part of `new_rule` (x)
            new_rule_then (np.ndarray): then part of `new_rule` (y)
            new_rule_fitness (np.ndarray): fitness of the `new_rule`
        """
        same_class_indices = self._class_indices[self._label_to_int(new_rule_then)]
        covered = self._covered(self._extants_if[same_class_indices], new_rule_if)
        covered_mask = np.zeros(len(same_class_indices), dtype=bool)
        covered_mask[:self._cardinality] = covered
        self._extants_covered[same_class_indices[covered_mask]] = True
        self._extants_covered[index] = False  # -> except new rule from covered
        self._extants_if[index], self._extants_then[index], self._fitnesses[index] = (
            new_rule_if,
            new_rule_then,
            new_rule_fitness,
        )

    def _label_to_int(self, label: np.ndarray) -> int:
        """Converts dummy label to int
        Args:
            label (np.ndarray): label to convert
        Returns:
            int: converted label
        """
        return int(np.argmax(label))

    def _generalize_extants(self):
        """Generalize the extants by flipping every 0 to a 1 and checking if the fitness improves."""
        new_extants_if = np.zeros_like(self._extants_if, dtype=bool)
        for i in range(len(self._extants_if)):
            for j in range(len(self._extants_if[i])):
                if not self._extants_if[i][j]:
                    self._extants_if[i][j] = True
                    fitness = self._fitness_fn(
                        self._extants_if[i], self._extants_then[i]
                    )
                    if fitness > self._fitnesses[i]:
                        self._fitnesses[i] = fitness
                    else:
                        self._extants_if[i][j] = False
            new_extants_if[i] = self._extants_if[i]
        self._extants_if = new_extants_if


    def getNumOfRules(self):
        return len(self._final_rules_if);

    def reduceRules(self):
        assert self._has_fit, "ROPAC has not been fit yet."
        i = 0;
        j = 0;
        while(i < len(self._final_rules_if)-1):
            j = i+1;
            coveredIndex = [];
            while(j < len(self._final_rules_if)):
                covered = True;
                for t in range(len(self._final_rules_if[j])):
                    if self._final_rules_if[j][t] and not self._final_rules_if[i][t]:
                        covered = False;
                        break;
                if covered :
                    coveredIndex.append(j);
                j += 1;
            self._final_rules_if = np.delete(self._final_rules_if, coveredIndex, axis = 0);
            self._final_rules_then = np.delete(self._final_rules_then, coveredIndex, axis = 0);
            self._fitnesses = np.delete(self._fitnesses, coveredIndex, axis = 0);
            i += 1;

# %%
import os
import time
from datetime import datetime

from scipy.io import arff
import pandas as pd
import numpy as np
from scipy.io import arff
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import KFold
import gc
from itertools import product


"""
# Convert the ARFF data to a structured NumPy array
data_array = np.array(data.tolist(), dtype=data.dtype)
print("Data Array Shape:", data_array.shape)

# Separate features (X) and labels (y)
X = data_array[:,:-1] # Features
y = data_array[:,-1]  # Labels

# Modify the dataset path below to test other ARFF files.
"""

# Uncomment this part if you wanna read from google drive
# folder_path = "/content/drive/MyDrive/content/data/"
# for file_name in os.listdir(folder_path):
#     if file_name.endswith(".arff"):
#         print(f'Reading {file_name}')
#         file_path = os.path.join(folder_path, file_name)
#         data, meta = arff.loadarff(file_path)



outputDir = 'result';

file_list = ['analcatdata_asbestos','breastTumor','chatfield_4','chscase_vine1', 'heart-statlog', 'cmc', 
             'diabetes','ecoli','eucalyptus','fertility','fruitfly' ,'heart-h','kr-vs-kp','liver-disorders',
             'monks-problems-2','mux6','parity5_plus_5', 'lymph', 'parkinsons','pbc','pyrim','seeds','servo',
             'tokyo1','stock', 'Statlog','threeOf9','vote', 'wdbc','xd6' ]

for file_name in file_list:
    data, meta = arff.loadarff("data/" + file_name + ".arff")
    outputPath = outputDir + "/" + file_name
    os.makedirs(outputPath,  exist_ok=True)
    dataTypes = meta.types();

    dataSet = pd.DataFrame(data).values;
    n_splits1 = 10;
    print(f"\t ******* Final results for {file_name} and {n_splits1} folds:")

    valid_combinations = []
    for algorithm in Algorithm:
        if algorithm.name == "RACER":
            valid_combinations = [
            (False, False, False),
            (True, False, False),
            ]
        else:
            valid_combinations = [
            (False, True, False),
            (False, True, True),
            (True, True, False),
            (True, True, True),
            ]

        for stop_merging, sorting, reverse in valid_combinations:
            preprocessor = ROPACPreprocesser();
            X, y = preprocessor.fit_transform(dataSet, dataTypes);
            # print(f'length of x is {len(X)} \n X: {X} ')
            # print(f'length of y is {len(y)} \ny: {y}')
            accuracy = 0 ;
            F1 = 0 ;
            numOfRules = 0;

            kf = KFold(n_splits=n_splits1 , random_state=1 , shuffle=True)
            
            i=0
            train_total_time = 0
            test_total_time = 0
            
            print(f"\n \t algorithm={algorithm.name}, stop_merging={stop_merging}, sorting={sorting}, reverse={reverse}")
            
            for train_index, test_index in kf.split(X):
                print(f'index: {i}')
                X_train , X_test , Y_train , Y_test = [] , [] , [] , []
                X_train , X_test = X[train_index] , X[test_index]
                Y_train , Y_test = y[train_index] , y[test_index]
                
                train_start_time = time.time()
                ropac = None
                ropac = ROPAC(alpha = 0.99, gamma = 0.6, suppress_warnings = True)
                ropac.fit(X_train, Y_train, stop_merging=stop_merging, algorithm=algorithm , sorting=sorting, reverse = reverse)
                ropac.reduceRules()
                train_end_time = time.time()
                
                test_start_time = time.time()
                metrics = ropac.score(X_test, Y_test)
                test_end_time = time.time()
                
                train_total_time += (train_end_time - train_start_time)
                test_total_time += (test_end_time - test_start_time)
                
                rules = ropac.getNumOfRules()
                numOfRules += rules
                accuracy += metrics['accuracy']
                F1 += metrics['f1_score']
                
                # print("\nResults for the fold {0}:".format(i))
                # print("Number of rules generated: {2}, Accuracy: {0}, F1 Score: {1}".format(metrics['accuracy'], metrics['f1_score'] , rules))
                # ropac.display_rules()
                
                i=i+1
                gc.collect()
                # break


            # confige_end_time = time.time()
            # total_time = confige_end_time - config_start_time
            train_avg_time = train_total_time / n_splits1
            test_avg_time = test_total_time / n_splits1

            # outputPath = outputDir+"/"+datasetName;
            # os.mkdir(outputPath);
            # output = open(outputPath+"/result.txt", "w");
            
            print(f"\tAve rules generated *** Ave accuracy *** Ave F1 ***  {numOfRules/10}  \t \t  {round((accuracy/10)*100, 2)} \t \t  {round(F1/10, 2)}")



            with open(outputPath + "/result.txt", "a") as output:
                current_time_string = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                output.write(f"----------- \n \t current_time_string : {current_time_string}")
                output.write(f"\n \t algorithm={algorithm.name}, stop_merging={stop_merging}, sorting={sorting}, reverse={reverse}")
                output.write(
                    f"\n \tAve rules: {numOfRules/n_splits1}\n"
                    f"\tAve accuracy: {round((accuracy/n_splits1)*100, 2)}%\n"
                    f"\tAve F1: {round(F1/n_splits1, 2)}\n"
                    f"\tTotal Train time: {round(train_total_time, 2)} seconds\n"
                    f"\tAvg Train time per fold: {round(train_avg_time, 4)} seconds\n"
                    f"\tTotal Test time: {round(test_total_time, 2)} seconds\n"
                    f"\tAvg Test time per fold: {round(test_avg_time, 4)} seconds\n"
                )
# Out:
# 	 ******* Final results for heart-statlog and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  43.3  	 	  79.26 	 	  0.79
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  64.4  	 	  77.04 	 	  0.77
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  38.5  	 	  75.93 	 	  0.76
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  42.1  	 	  79.26 	 	  0.79
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  57.0  	 	  79.26 	 	  0.79
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  65.9  	 	  83.33 	 	  0.84
# 	 ******* Final results for breastTumor and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  49.8  	 	  53.53 	 	  0.52
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  83.8  	 	  55.62 	 	  0.55
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  49.2  	 	  51.44 	 	  0.5
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  44.6  	 	  55.94 	 	  0.55
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  81.5  	 	  55.94 	 	  0.55
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  81.4  	 	  58.08 	 	  0.57
# 	 ******* Final results for xd6 and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  29.7  	 	  99.9 	 	  1.0
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  30.2  	 	  100.0 	 	  1.0
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  28.9  	 	  99.9 	 	  1.0
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  30.0  	 	  100.0 	 	  1.0
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  30.9  	 	  99.9 	 	  1.0
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  30.2  	 	  100.0 	 	  1.0
# 	 ******* Final results for cmc and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  70.1  	 	  65.17 	 	  0.62
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  161.4  	 	  67.41 	 	  0.66
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  55.8  	 	  66.46 	 	  0.63
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  68.5  	 	  65.99 	 	  0.62
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  156.4  	 	  65.85 	 	  0.63
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  179.3  	 	  67.68 	 	  0.65
# 	 ******* Final results for breastTumor and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  49.8  	 	  53.53 	 	  0.52
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  83.8  	 	  55.62 	 	  0.55
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  49.2  	 	  51.44 	 	  0.5
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  44.6  	 	  55.94 	 	  0.55
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  81.5  	 	  55.94 	 	  0.55
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  81.4  	 	  58.08 	 	  0.57
# 	 ******* Final results for parity5_plus_5 and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  32.2  	 	  100.0 	 	  1.0
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  32.3  	 	  100.0 	 	  1.0
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  32.2  	 	  100.0 	 	  1.0
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  32.0  	 	  100.0 	 	  1.0
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  33.2  	 	  100.0 	 	  1.0
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  32.5  	 	  100.0 	 	  1.0
# 	 ******* Final results for diabetes and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  11.4  	 	  66.93 	 	  0.58
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  35.9  	 	  71.21 	 	  0.67
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  2.3  	 	  66.79 	 	  0.55
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  15.8  	 	  68.76 	 	  0.61
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  24.0  	 	  68.48 	 	  0.59
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  37.5  	 	  72.0 	 	  0.69
# 	 ******* Final results for tokyo1 and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  45.3  	 	  92.91 	 	  0.93
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  88.4  	 	  92.39 	 	  0.92
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  34.8  	 	  90.82 	 	  0.91
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  45.9  	 	  93.22 	 	  0.93
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  76.0  	 	  91.24 	 	  0.91
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  104.2  	 	  92.49 	 	  0.92
# 	 ******* Final results for stock and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  14.0  	 	  88.32 	 	  0.88
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  14.3  	 	  88.32 	 	  0.88
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  10.0  	 	  85.37 	 	  0.85
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  15.5  	 	  92.95 	 	  0.93
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  12.3  	 	  87.05 	 	  0.87
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  15.2  	 	  92.95 	 	  0.93
# 	 ******* Final results for kr-vs-kp and 10 folds:
#
#  	 algorithm=RACER, stop_merging=False, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  36.3  	 	  99.22 	 	  0.99
#
#  	 algorithm=RACER, stop_merging=True, sorting=False, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  199.4  	 	  98.44 	 	  0.98
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  43.3  	 	  99.37 	 	  0.99
#
#  	 algorithm=RACRANK, stop_merging=False, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  36.3  	 	  99.09 	 	  0.99
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=False
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  161.7  	 	  99.0 	 	  0.99
#
#  	 algorithm=RACRANK, stop_merging=True, sorting=True, reverse=True
# i: 0
# i: 1
# i: 2
# i: 3
# i: 4
# i: 5
# i: 6
# i: 7
# i: 8
# i: 9
# 	Ave rules generated *** Ave accuracy *** Ave F1 ***  193.9  	 	  98.69 	 	  0.99
